# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir /content/drive/MyDrive/Github/
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Github/’: File exists

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %%
username = 'cmonkl'
repository = 'Product-image-generation-from-text-description'

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'Product-image-generation-from-text-description'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 2), reused 2 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), 2.73 KiB | 14.00 KiB/s, done.

# %%
# %cd {repository}
# %ls -a
# Out:
# /content/drive/MyDrive/Github/Product-image-generation-from-text-description
# .git/  .gitignore

# %%
# %cd {repository}

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !echo "# test" >> README.md

# %%
# %ls
# Out:
# Product-image-generation-from-text-description/

# %%
# !git add .

# %%
# !git config --global user.email 'cmon86559@gmail.com'
# !git config --global user.name 'cmonkl'

# %%
# !git commit -m "modified 6"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
